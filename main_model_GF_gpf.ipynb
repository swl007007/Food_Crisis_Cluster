# %%
# @Author: xie
# @Date:   2025-06-20
# @Email:  xie@umd.edu
# @Last modified by:   xie
# @Last modified time: 2025-06-20
# @License: MIT License

'''
GeoRF_main.py

This file shows an example on how to define, train and evaluate a GeoRF model.
The general usage is similar to standard machine learning models, with fit(), predict() and evaluate() functions.
The main difference is that GeoRF is a spatially-explicit model, which means location info is needed as part of inputs.

Usage:
		There are 4 key steps:
			(1) Data loading: Prepare standard X, y, as well as locations X_loc
			(2) Define groups using GroupGenerator() or by customizing it for your own data: This is needed in GeoRF, which defines the minimum spatial unit for space partitioning.
					For example, a grid can be used to split the study area into groups, where all data points in each grid cell form a group.
					The data may contain thousands of groups, which may be partitioned by GeoRF into 10-20 partitions (one RF per partition). This is just to give a sense of the quantities.
					In testing, the grouping is used to assign test data points to local models (one local RF model is learned for each partition).
			(3) Training: georf.fit()
			(4) Prediction and evaluation: georf.predict() and georf.evaluate()

		For visualizations, code for grid-based grouping is provided. For other group definitions, please write customized visualization functions.
'''

import numpy as np
from scipy import stats
import pandas as pd
import os
import argparse
import sys
#GeoRF
#Can be customized with the template
from GeoRF import GeoRF
from customize import *
from data import load_demo_data#load_data_us_cdl
from helper import get_spatial_range
from initialization import train_test_split_all
#All global parameters
from config import *
from sklearn.impute import SimpleImputer
import polars as pl
# import machine learning metrics, precision, recall and f1_score
from sklearn.metrics import precision_score, recall_score, f1_score

data = pl.read_csv(r"C:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\1.Source Data\FEWSNET_IPC_train_lag_forecast_v06252025.csv")
# drop ISO3, fews_ipc_adjusted, fews_proj_med_adjusted, fews_ipc,fews_proj_near, fews_proj_near_ha, fews_proj_med, fews_proj_med_ha, ADMIN0, ADMIN1,ADMIN2,ADMIN3,ISO

# %%
# customize function
def comp_impute(X, strategy = "max_plus", multiplier = 100.0):
    # loop over X columns, replace inf with missing
    for _ in range(X.shape[1]):
        print(f"Checking column {_} for inf values")
        # Try to convert column to float, ignore errors (non-convertible values remain unchanged)
        col_data = X[:, _]
        try:
            col_data_float = col_data.astype(float)
            if np.isinf(col_data_float).any():
                print(f"Column {_} has inf values, replacing with NaN")
                col_data_float[np.isinf(col_data_float)] = np.nan
                X[:, _] = col_data_float
        except Exception as e:
            print(f"Column {_} could not be converted to float: {e}")
            # Skip columns that cannot be converted
            continue
    X_imputed, imputer = impute_missing_values(X, strategy=strategy, multiplier=multiplier, verbose=True)
    X = X_imputed
    return X

# %%
# determine xmin,xmax,ymin and ymax first before runing model

# %%
# Data Preprocessing
cols_to_drop = [
        "ISO3", "fews_ipc_adjusted", "fews_proj_med_adjusted", "fews_ipc",
        "fews_proj_near", "fews_proj_near_ha", "fews_proj_med",
        "fews_proj_med_ha", "ADMIN0", "ADMIN1", "ADMIN2", "ADMIN3"
    ]
data = data.drop(cols_to_drop)



# keep only fews_ipc_crisis is not null
data = data.filter(pl.col("fews_ipc_crisis").is_not_null())
# drop unit name, ISO
data = data.drop(["unit_name", "ISO"])
# for AEZ_* replace "False" with 0 and "True" with 1
for col in data.columns:
    if col.startswith("AEZ_"):
        data = data.with_columns(
            pl.when(pl.col(col) == "True")
            .then(1)
            .when(pl.col(col) == "False")
            .then(0)
            .otherwise(pl.col(col))
            .alias(col)
        )
df = data.to_pandas()

X_loc = df[['lat', 'lon']].values



#prepare groups (minimum spatial units for space-partitioning and location groupings, e.g., using a grid)
STEP_SIZE = 0.1
#extract the values of FEWSNET_admin_code and assign to X_group
X_group = df['FEWSNET_admin_code'].values
# convert to integer
X_group = X_group.astype(int)

y = df['fews_ipc_crisis'].values


#X impute with column mean


df['date'] = pd.to_datetime(df['date'])
df['years'] = df['date'].dt.year

# sort by FEWSNET_admin_code and date
df = df.sort_values(by=['FEWSNET_admin_code', 'date'])
# for each FEWSNET_admin_code, created lagged fews_ipc_crisis for 1,2 and 3 terms
for lag in range(1, 4):
    df[f'fews_ipc_crisis_lag_{lag}'] = df.groupby('FEWSNET_admin_code')['fews_ipc_crisis'].shift(lag)
# drop date
df = df.drop(columns=['date'])
df=df.drop(columns=['fews_ipc_crisis', 'lat', 'lon'])
time_variants =  ['event_count_battles', 'event_count_explosions', 'event_count_violence', 'sum_fatalities_battles', 'sum_fatalities_explosions', 'sum_fatalities_violence', 'event_count_battles_w5', 'event_count_explosions_w5', 'event_count_violence_w5', 'sum_fatalities_battles_w5', 'sum_fatalities_explosions_w5', 'sum_fatalities_violence_w5', 'event_count_battles_w10', 'event_count_explosions_w10', 'event_count_violence_w10', 'sum_fatalities_battles_w10', 'sum_fatalities_explosions_w10', 'sum_fatalities_violence_w10', 'nightlight', 'nightlight_sd', 'EVI', 'EVI_stdDev',  'FAO_price', 'Evap_tavg_mean', 'Evap_tavg_stdDev', 'LWdown_f_tavg_mean', 'LWdown_f_tavg_stdDev', 'Lwnet_tavg_mean', 'Lwnet_tavg_stdDev', 'Psurf_f_tavg_mean', 'Psurf_f_tavg_stdDev', 'Qair_f_tavg_mean', 'Qair_f_tavg_stdDev', 'Qg_tavg_mean', 'Qg_tavg_stdDev', 'Qh_tavg_mean', 'Qh_tavg_stdDev', 'Qle_tavg_mean', 'Qle_tavg_stdDev', 'Qs_tavg_mean', 'Qs_tavg_stdDev', 'Qsb_tavg_mean', 'Qsb_tavg_stdDev', 'RadT_tavg_mean', 'RadT_tavg_stdDev', 'Rainf_f_tavg_mean', 'Rainf_f_tavg_stdDev', 'SnowCover_inst_mean', 'SnowCover_inst_stdDev', 'SnowDepth_inst_mean', 'SnowDepth_inst_stdDev', 'Snowf_tavg_mean', 'Snowf_tavg_stdDev', 'SoilMoi00_10cm_tavg_mean', 'SoilMoi00_10cm_tavg_stdDev', 'SoilMoi10_40cm_tavg_mean', 'SoilMoi10_40cm_tavg_stdDev', 'SoilMoi100_200cm_tavg_mean', 'SoilMoi100_200cm_tavg_stdDev', 'SoilMoi40_100cm_tavg_mean', 'SoilMoi40_100cm_tavg_stdDev', 'SoilTemp00_10cm_tavg_mean', 'SoilTemp00_10cm_tavg_stdDev', 'SoilTemp10_40cm_tavg_mean', 'SoilTemp10_40cm_tavg_stdDev', 'SoilTemp100_200cm_tavg_mean', 'SoilTemp100_200cm_tavg_stdDev', 'SoilTemp40_100cm_tavg_mean', 'SoilTemp40_100cm_tavg_stdDev', 'SWdown_f_tavg_mean', 'SWdown_f_tavg_stdDev', 'SWE_inst_mean', 'SWE_inst_stdDev', 'Swnet_tavg_mean', 'Swnet_tavg_stdDev', 'Tair_f_tavg_mean', 'Tair_f_tavg_stdDev', 'Wind_f_tavg_mean', 'Wind_f_tavg_stdDev', 'gpp_sd', 'gpp_mean', 'CPI', 'GDP', 'CC', 'gini', 'WFP_Price', 'WFP_Price_std']
time_variants_m12 = [variant + '_m12' for variant in time_variants]
time_variants_list = time_variants + time_variants_m12
l2_index = []
# if columns in time_variants_list, record its index and restore in l2_index
for i, col in enumerate(df.columns):
    if col in time_variants_list:
        l2_index.append(i)

# %%
# l1 index is all columns except l2 index
l1_index = [i for i in range(df.shape[1]) if i not in l2_index]

X = df.values
X = comp_impute(X)
# Out:
# Checking column 0 for inf values
# Checking column 1 for inf values
# Checking column 2 for inf values
# Checking column 3 for inf values
# Checking column 4 for inf values
# Checking column 5 for inf values
# Checking column 6 for inf values
# Checking column 7 for inf values
# Checking column 8 for inf values
# Checking column 9 for inf values
# Checking column 10 for inf values
# Checking column 11 for inf values
# Checking column 12 for inf values
# Checking column 13 for inf values
# Checking column 14 for inf values
# Checking column 15 for inf values
# Checking column 16 for inf values
# Checking column 17 for inf values
# Checking column 18 for inf values
# Checking column 19 for inf values
# Checking column 20 for inf values
# Checking column 21 for inf values
# Checking column 22 for inf values
# Checking column 23 for inf values
# Checking column 24 for inf values
# Checking column 25 for inf values
# Checking column 26 for inf values
# Checking column 27 for inf values
# Checking column 28 for inf values
# Checking column 29 for inf values
# Checking column 30 for inf values
# Checking column 31 for inf values
# Checking column 32 for inf values
# Checking column 33 for inf values
# Checking column 34 for inf values
# Checking column 35 for inf values
# Checking column 36 for inf values
# Checking column 37 for inf values
# Checking column 38 for inf values
# Checking column 39 for inf values
# Checking column 40 for inf values
# Checking column 41 for inf values
# Checking column 42 for inf values
# Checking column 43 for inf values
# Checking column 44 for inf values
# Checking column 45 for inf values
# Checking column 46 for inf values
# Checking column 47 for inf values
# Checking column 48 for inf values
# Checking column 49 for inf values
# Checking column 50 for inf values
# Checking column 51 for inf values
# Checking column 52 for inf values
# Checking column 53 for inf values
# Checking column 54 for inf values
# Checking column 55 for inf values
# Checking column 56 for inf values
# Checking column 57 for inf values
# Checking column 58 for inf values
# Checking column 59 for inf values
# Checking column 60 for inf values
# Checking column 61 for inf values
# Checking column 62 for inf values
# Checking column 63 for inf values
# Checking column 64 for inf values
# Checking column 65 for inf values
# Checking column 66 for inf values
# Checking column 67 for inf values
# Checking column 68 for inf values
# Checking column 69 for inf values
# Checking column 70 for inf values
# Checking column 71 for inf values
# Checking column 72 for inf values
# Checking column 73 for inf values
# Checking column 74 for inf values
# Checking column 75 for inf values
# Checking column 76 for inf values
# Checking column 77 for inf values
# Checking column 78 for inf values
# Checking column 79 for inf values
# Checking column 80 for inf values
# Checking column 81 for inf values
# Checking column 82 for inf values
# Checking column 83 for inf values
# Checking column 84 for inf values
# Checking column 85 for inf values
# Checking column 86 for inf values
# Checking column 87 for inf values
# Checking column 88 for inf values
# Checking column 89 for inf values
# Checking column 90 for inf values
# Checking column 91 for inf values
# Checking column 92 for inf values
# Checking column 93 for inf values
# Checking column 94 for inf values
# Checking column 95 for inf values
# Checking column 96 for inf values
# Checking column 97 for inf values
# Checking column 98 for inf values
# Checking column 99 for inf values
# Checking column 100 for inf values
# Checking column 101 for inf values
# Checking column 102 for inf values
# Checking column 103 for inf values
# Checking column 104 for inf values
# Checking column 105 for inf values
# Checking column 106 for inf values
# Checking column 107 for inf values
# Checking column 108 for inf values
# Checking column 109 for inf values
# Checking column 110 for inf values
# Checking column 111 for inf values
# Checking column 112 for inf values
# Checking column 113 for inf values
# Checking column 114 for inf values
# Checking column 115 for inf values
# Checking column 116 for inf values
# Checking column 117 for inf values
# Checking column 118 for inf values
# Checking column 119 for inf values
# Checking column 120 for inf values
# Checking column 121 for inf values
# Checking column 122 for inf values
# Checking column 123 for inf values
# Checking column 124 for inf values
# Checking column 125 for inf values
# Checking column 126 for inf values
# Checking column 127 for inf values
# Checking column 128 for inf values
# Checking column 129 for inf values
# Checking column 130 for inf values
# Checking column 131 for inf values
# Checking column 132 for inf values
# Checking column 133 for inf values
# Checking column 134 for inf values
# Checking column 135 for inf values
# Checking column 136 for inf values
# Checking column 137 for inf values
# Checking column 138 for inf values
# Checking column 139 for inf values
# Checking column 140 for inf values
# Checking column 141 for inf values
# Checking column 142 for inf values
# Checking column 143 for inf values
# Checking column 144 for inf values
# Checking column 145 for inf values
# Checking column 146 for inf values
# Checking column 147 for inf values
# Checking column 148 for inf values
# Checking column 149 for inf values
# Checking column 150 for inf values
# Checking column 151 for inf values
# Checking column 152 for inf values
# Checking column 153 for inf values
# Checking column 154 for inf values
# Checking column 155 for inf values
# Checking column 156 for inf values
# Checking column 157 for inf values
# Checking column 158 for inf values
# Checking column 159 for inf values
# Checking column 160 for inf values
# Checking column 161 for inf values
# Checking column 162 for inf values
# Checking column 163 for inf values
# Checking column 164 for inf values
# Checking column 165 for inf values
# Checking column 166 for inf values
# Checking column 167 for inf values
# Checking column 168 for inf values
# Checking column 169 for inf values
# Checking column 170 for inf values
# Checking column 171 for inf values
# Checking column 172 for inf values
# Checking column 173 for inf values
# Checking column 174 for inf values
# Checking column 175 for inf values
# Checking column 176 for inf values
# Checking column 177 for inf values
# Checking column 178 for inf values
# Checking column 179 for inf values
# Checking column 180 for inf values
# Checking column 181 for inf values
# Checking column 182 for inf values
# Checking column 183 for inf values
# Checking column 184 for inf values
# Checking column 185 for inf values
# Checking column 186 for inf values
# Checking column 187 for inf values
# Checking column 188 for inf values
# Checking column 189 for inf values
# Checking column 190 for inf values
# Checking column 191 for inf values
# Checking column 192 for inf values
# Checking column 193 for inf values
# Checking column 194 for inf values
# Checking column 195 for inf values
# Checking column 196 for inf values
# Checking column 197 for inf values
# Checking column 198 for inf values
# Checking column 199 for inf values
# Checking column 200 for inf values
# Checking column 201 for inf values
# Checking column 202 for inf values
# Checking column 203 for inf values
# Checking column 204 for inf values
# Checking column 205 for inf values
# Checking column 206 for inf values
# Checking column 207 for inf values
# Checking column 208 for inf values
# Checking column 209 for inf values
# Checking column 210 for inf values
# Checking column 211 for inf values
# Checking column 212 for inf values
# Checking column 213 for inf values
# Checking column 214 for inf values
# Checking column 215 for inf values
# Checking column 216 for inf values
# Checking column 217 for inf values
# Checking column 218 for inf values
# Checking column 219 for inf values
# Checking column 220 for inf values
# Checking column 221 for inf values
# Checking column 222 for inf values
# Checking column 223 for inf values
# Checking column 224 for inf values
# Checking column 225 for inf values
# Checking column 226 for inf values
# Checking column 227 for inf values
# Checking column 228 for inf values
# Checking column 229 for inf values
# Checking column 230 for inf values
# Checking column 231 for inf values
# Checking column 232 for inf values
# Checking column 233 for inf values
# Checking column 234 for inf values
# Checking column 235 for inf values
# Checking column 236 for inf values
# Checking column 237 for inf values
# Checking column 238 for inf values
# Checking column 239 for inf values
# Checking column 240 for inf values
# Checking column 241 for inf values
# Checking column 242 for inf values
# Checking column 243 for inf values
# Checking column 244 for inf values
# Checking column 245 for inf values
# Checking column 246 for inf values
# Checking column 247 for inf values
# Checking column 248 for inf values
# Checking column 249 for inf values
# Checking column 250 for inf values
# Checking column 251 for inf values
# Checking column 252 for inf values
# Checking column 253 for inf values
# Checking column 254 for inf values
# Checking column 255 for inf values
# Checking column 256 for inf values
# Checking column 257 for inf values
# Checking column 258 for inf values
# Checking column 259 for inf values
# Checking column 260 for inf values
# Checking column 261 for inf values
# Checking column 262 for inf values
# Checking column 263 for inf values
# Checking column 264 for inf values
# Checking column 265 for inf values
# Column 265 has inf values, replacing with NaN
# Checking column 266 for inf values
# Column 266 has inf values, replacing with NaN
# Checking column 267 for inf values
# Checking column 268 for inf values
# Checking column 269 for inf values
# Checking column 270 for inf values
# Checking column 271 for inf values
# Checking column 272 for inf values
# Checking column 273 for inf values
# Checking column 274 for inf values
# Checking column 275 for inf values
# Checking column 276 for inf values
# Checking column 277 for inf values
# Checking column 278 for inf values
# Checking column 279 for inf values
# Checking column 280 for inf values
# Checking column 281 for inf values
# Checking column 282 for inf values
# Checking column 283 for inf values
# Checking column 284 for inf values
# Checking column 285 for inf values
# Checking column 286 for inf values
# Checking column 287 for inf values
# Checking column 288 for inf values
# Checking column 289 for inf values
# Checking column 290 for inf values
# Checking column 291 for inf values
# Checking column 292 for inf values
# Checking column 293 for inf values
# Checking column 294 for inf values
# Checking column 295 for inf values
# Checking column 296 for inf values
# Checking column 297 for inf values
# Checking column 298 for inf values
# Checking column 299 for inf values
# Checking column 300 for inf values
# Checking column 301 for inf values
# Checking column 302 for inf values
# Checking column 303 for inf values
# Checking column 304 for inf values
# Checking column 305 for inf values
# Checking column 306 for inf values
# Checking column 307 for inf values
# Checking column 308 for inf values
# Checking column 309 for inf values
# Checking column 310 for inf values
# Checking column 311 for inf values
# Checking column 312 for inf values
# Checking column 313 for inf values
# Checking column 314 for inf values
# Checking column 315 for inf values
# Checking column 316 for inf values
# Checking column 317 for inf values
# Checking column 318 for inf values
# Checking column 319 for inf values
# Checking column 320 for inf values
# Checking column 321 for inf values
# Checking column 322 for inf values
# Checking column 323 for inf values
# Checking column 324 for inf values
# Checking column 325 for inf values
# Checking column 326 for inf values
# Checking column 327 for inf values
# Checking column 328 for inf values
# Checking column 329 for inf values
# Checking column 330 for inf values
# Checking column 331 for inf values
# Checking column 332 for inf values
# Checking column 333 for inf values
# Checking column 334 for inf values
# Checking column 335 for inf values
# Checking column 336 for inf values
# Checking column 337 for inf values
# Checking column 338 for inf values
# Checking column 339 for inf values
# Checking column 340 for inf values
# Checking column 341 for inf values
# Checking column 342 for inf values
# Checking column 343 for inf values
# Checking column 344 for inf values
# Checking column 345 for inf values
# Checking column 346 for inf values
# Checking column 347 for inf values
# Checking column 348 for inf values
# Checking column 349 for inf values
# Checking column 350 for inf values
# Checking column 351 for inf values
# Checking column 352 for inf values
# Checking column 353 for inf values
# Checking column 354 for inf values
# Checking column 355 for inf values
# Checking column 356 for inf values
# Checking column 357 for inf values
# Checking column 358 for inf values
# Checking column 359 for inf values
# Checking column 360 for inf values
# Checking column 361 for inf values
# Checking column 362 for inf values
# Checking column 363 for inf values
# Checking column 364 for inf values
# Checking column 365 for inf values
# Checking column 366 for inf values
# Checking column 367 for inf values
# Checking column 368 for inf values
# Checking column 369 for inf values
# Checking column 370 for inf values
# Checking column 371 for inf values
# Checking column 372 for inf values
# Checking column 373 for inf values
# Checking column 374 for inf values
# Checking column 375 for inf values
# Checking column 376 for inf values
# Checking column 377 for inf values
# Checking column 378 for inf values
# Checking column 379 for inf values
# Checking column 380 for inf values
# Checking column 381 for inf values
# Checking column 382 for inf values
# Checking column 383 for inf values
# Checking column 384 for inf values
# Checking column 385 for inf values
# Checking column 386 for inf values
# Checking column 387 for inf values
# Checking column 388 for inf values
# Checking column 389 for inf values
# Checking column 390 for inf values
# Checking column 391 for inf values
# Checking column 392 for inf values
# Checking column 393 for inf values
# Checking column 394 for inf values
# Checking column 395 for inf values
# Checking column 396 for inf values
# Checking column 397 for inf values
# Checking column 398 for inf values
# Checking column 399 for inf values
# Checking column 400 for inf values
# Checking column 401 for inf values
# Checking column 402 for inf values
# Checking column 403 for inf values
# Checking column 404 for inf values
# Checking column 405 for inf values
# Checking column 406 for inf values
# Checking column 407 for inf values
# Checking column 408 for inf values
# Checking column 409 for inf values
# Checking column 410 for inf values
# Checking column 411 for inf values
# Checking column 412 for inf values
# Checking column 413 for inf values
# Checking column 414 for inf values
# Checking column 415 for inf values
# Checking column 416 for inf values
# Checking column 417 for inf values
# Checking column 418 for inf values
# Checking column 419 for inf values
# Checking column 420 for inf values
# Checking column 421 for inf values
# Checking column 422 for inf values
# Checking column 423 for inf values
# Checking column 424 for inf values
# Checking column 425 for inf values
# Checking column 426 for inf values
# Checking column 427 for inf values
# Checking column 428 for inf values
# Checking column 429 for inf values
# Checking column 430 for inf values
# Checking column 431 for inf values
# Checking column 432 for inf values
# Checking column 433 for inf values
# Checking column 434 for inf values
# Checking column 435 for inf values
# Checking column 436 for inf values
# Checking column 437 for inf values
# Checking column 438 for inf values
# Checking column 439 for inf values
# Checking column 440 for inf values
# Checking column 441 for inf values
# Checking column 442 for inf values
# Checking column 443 for inf values
# Checking column 444 for inf values
# Checking column 445 for inf values
# Checking column 446 for inf values
# Checking column 447 for inf values
# Checking column 448 for inf values
# Checking column 449 for inf values
# Checking column 450 for inf values
# Checking column 451 for inf values
# Checking column 452 for inf values
# Checking column 453 for inf values
# Checking column 454 for inf values
# Checking column 455 for inf values
# Checking column 456 for inf values
# Checking column 457 for inf values
# Checking column 458 for inf values
# Checking column 459 for inf values
# Checking column 460 for inf values
# Checking column 461 for inf values
# Checking column 462 for inf values
# Checking column 463 for inf values
# Checking column 464 for inf values
# Checking column 465 for inf values
# Checking column 466 for inf values
# Checking column 467 for inf values
# Checking column 468 for inf values
# Checking column 469 for inf values
# Checking column 470 for inf values
# Checking column 471 for inf values
# Checking column 472 for inf values
# Checking column 473 for inf values
# Checking column 474 for inf values
# Checking column 475 for inf values
# Checking column 476 for inf values
# Checking column 477 for inf values
# Checking column 478 for inf values
# Checking column 479 for inf values
# Checking column 480 for inf values
# Checking column 481 for inf values
# Checking column 482 for inf values
# Checking column 483 for inf values
# Checking column 484 for inf values
# Checking column 485 for inf values
# Checking column 486 for inf values
# Checking column 487 for inf values
# Checking column 488 for inf values
# Checking column 489 for inf values
# Checking column 490 for inf values
# Checking column 491 for inf values
# Checking column 492 for inf values
# Checking column 493 for inf values
# Checking column 494 for inf values
# Checking column 495 for inf values
# Checking column 496 for inf values
# Checking column 497 for inf values
# Checking column 498 for inf values
# Checking column 499 for inf values
# Starting imputation with strategy: max_plus, multiplier: 100.0
# Original data shape: (185003, 500)
# Original data type: <class 'numpy.ndarray'>
# Original data dtype: object
#
# Data type analysis:
#   object: 500 columns
#
# Total missing values: 3847051
# Missing values per column (showing first 10 columns with missing data):
#   Column 45: 4916 (2.7%)
#   Column 46: 4916 (2.7%)
#   Column 84: 35078 (19.0%)
#   Column 85: 19141 (10.3%)
#   Column 86: 11836 (6.4%)
#   Column 87: 104517 (56.5%)
#   Column 88: 92121 (49.8%)
#   Column 89: 94438 (51.0%)
#   Column 90: 4 (0.0%)
#   Column 91: 4 (0.0%)
#   ... and 354 more columns with missing data
# Column 45: Imputed 4916 missing values with 49977.010
# Column 46: Imputed 4916 missing values with 100000.000
# Column 84: Imputed 35078 missing values with 55720.182
# Column 85: Imputed 19141 missing values with 1238938.587
# Column 86: Imputed 11836 missing values with 4428.571
# Column 87: Imputed 104517 missing values with 53.956
# Column 88: Imputed 92121 missing values with 459194.145
# Column 89: Imputed 94438 missing values with 290723.270
# Column 90: Imputed 4 missing values with 3400.000
# Column 91: Imputed 4 missing values with 1700.000
# Column 92: Imputed 4 missing values with 2200.000
# Column 93: Imputed 4 missing values with 40800.000
# Column 94: Imputed 4 missing values with 13800.000
# Column 95: Imputed 4 missing values with 298600.000
# Column 96: Imputed 4 missing values with 7900.000
# Column 97: Imputed 4 missing values with 2200.000
# Column 98: Imputed 4 missing values with 4200.000
# Column 99: Imputed 4 missing values with 51500.000
# Column 100: Imputed 4 missing values with 19400.000
# Column 101: Imputed 4 missing values with 298600.000
# Column 102: Imputed 4 missing values with 12400.000
# Column 103: Imputed 4 missing values with 6100.000
# Column 104: Imputed 4 missing values with 10500.000
# Column 105: Imputed 4 missing values with 63200.000
# Column 106: Imputed 4 missing values with 52700.000
# Column 107: Imputed 4 missing values with 321200.000
# Column 108: Imputed 4 missing values with 9842.578
# Column 109: Imputed 4 missing values with 5746.340
# Column 110: Imputed 4 missing values with 714900.000
# Column 111: Imputed 5326 missing values with 100000.000
# Column 112: Imputed 4 missing values with 0.009
# Column 113: Imputed 4 missing values with 43495.310
# Column 114: Imputed 4 missing values with 100.000
# Column 115: Imputed 4 missing values with 10227417.188
# Column 116: Imputed 4 missing values with 2.024
# Column 117: Imputed 4 missing values with 2282.692
# Column 118: Imputed 4 missing values with 19148.747
# Column 119: Imputed 4 missing values with 22327.636
# Column 120: Imputed 4 missing values with 0.020
# Column 121: Imputed 4 missing values with 0.016
# Column 122: Imputed 4 missing values with 31316.496
# Column 123: Imputed 4 missing values with 0.038
# Column 124: Imputed 4 missing values with 98.000
# Column 125: Imputed 4 missing values with 219.142
# Column 126: Imputed 4 missing values with 0.013
# Column 127: Imputed 4 missing values with 46.799
# Column 128: Imputed 4 missing values with 46.800
# Column 129: Imputed 4 missing values with 46.739
# Column 130: Imputed 4 missing values with 46.800
# Column 131: Imputed 4 missing values with 31300.539
# Column 132: Imputed 4 missing values with 31238.158
# Column 133: Imputed 4 missing values with 31106.306
# Column 134: Imputed 4 missing values with 30970.224
# Column 135: Imputed 4 missing values with 41683.658
# Column 136: Imputed 4 missing values with 56133.702
# Column 137: Imputed 4 missing values with 35731.003
# Column 138: Imputed 4 missing values with 31002.626
# Column 139: Imputed 4 missing values with 1604.128
# Column 140: Imputed 4 missing values with 6553500.000
# Column 141: Imputed 36526 missing values with 55720.182
# Column 142: Imputed 21224 missing values with 1238938.587
# Column 143: Imputed 13562 missing values with 4428.571
# Column 144: Imputed 104744 missing values with 53.956
# Column 145: Imputed 92402 missing values with 459194.145
# Column 146: Imputed 94309 missing values with 290723.270
# Column 168: Imputed 3802 missing values with 100000.000
# Column 198: Imputed 23756 missing values with 50688.568
# Column 199: Imputed 7977 missing values with 1238938.587
# Column 201: Imputed 93947 missing values with 53.895
# Column 202: Imputed 83097 missing values with 452194.325
# Column 203: Imputed 84504 missing values with 290723.270
# Column 204: Imputed 4 missing values with 2800.000
# Column 205: Imputed 4 missing values with 800.000
# Column 206: Imputed 4 missing values with 2158.333
# Column 207: Imputed 4 missing values with 16400.000
# Column 208: Imputed 4 missing values with 9200.000
# Column 209: Imputed 4 missing values with 34050.000
# Column 210: Imputed 4 missing values with 6800.000
# Column 211: Imputed 4 missing values with 1175.000
# Column 212: Imputed 4 missing values with 4458.333
# Column 213: Imputed 4 missing values with 16400.000
# Column 214: Imputed 4 missing values with 13316.667
# Column 215: Imputed 4 missing values with 34050.000
# Column 216: Imputed 4 missing values with 9541.667
# Column 217: Imputed 4 missing values with 5500.000
# Column 218: Imputed 4 missing values with 5833.333
# Column 219: Imputed 4 missing values with 45983.333
# Column 220: Imputed 4 missing values with 52700.000
# Column 221: Imputed 4 missing values with 36550.000
# Column 222: Imputed 4 missing values with 7249.119
# Column 223: Imputed 4 missing values with 4001.317
# Column 224: Imputed 4 missing values with 622694.771
# Column 225: Imputed 4019 missing values with 100000.000
# Column 226: Imputed 4 missing values with 0.007
# Column 227: Imputed 4 missing values with 42562.529
# Column 228: Imputed 4 missing values with 0.000
# Column 229: Imputed 4 missing values with 10162164.909
# Column 230: Imputed 4 missing values with 1.842
# Column 231: Imputed 4 missing values with 353.213
# Column 232: Imputed 4 missing values with 16445.865
# Column 233: Imputed 4 missing values with 16412.085
# Column 234: Imputed 4 missing values with 0.006
# Column 235: Imputed 4 missing values with 0.005
# Column 236: Imputed 4 missing values with 30941.603
# Column 237: Imputed 4 missing values with 0.015
# Column 238: Imputed 4 missing values with 68.294
# Column 239: Imputed 4 missing values with 93.000
# Column 240: Imputed 4 missing values with 0.003
# Column 241: Imputed 4 missing values with 42.843
# Column 242: Imputed 4 missing values with 43.160
# Column 243: Imputed 4 missing values with 44.072
# Column 244: Imputed 4 missing values with 46.800
# Column 245: Imputed 4 missing values with 30935.939
# Column 246: Imputed 4 missing values with 30912.118
# Column 247: Imputed 4 missing values with 30858.145
# Column 248: Imputed 4 missing values with 30792.804
# Column 249: Imputed 4 missing values with 32810.309
# Column 250: Imputed 4 missing values with 25414.142
# Column 251: Imputed 4 missing values with 29120.395
# Column 252: Imputed 4 missing values with 30701.252
# Column 253: Imputed 4 missing values with 985.460
# Column 254: Imputed 4 missing values with 6553500.000
# Column 255: Imputed 24587 missing values with 50688.568
# Column 256: Imputed 7981 missing values with 1238938.587
# Column 257: Imputed 4 missing values with 4357.143
# Column 258: Imputed 95091 missing values with 53.834
# Column 259: Imputed 83219 missing values with 452194.325
# Column 260: Imputed 84625 missing values with 290723.270
# Column 261: Imputed 30076 missing values with 100.000
# Column 263: Imputed 15724 missing values with 100000.000
# Column 264: Imputed 15724 missing values with 83580.068
# Column 265: Imputed 5974 missing values with 1101.027
# Column 266: Imputed 6055 missing values with 1071.781
# Column 268: Imputed 3121 missing values with 3900.000
# Column 269: Imputed 6602 missing values with 4500.000
# Column 270: Imputed 6602 missing values with 3400.000
# Column 271: Imputed 3121 missing values with 1700.000
# Column 272: Imputed 6602 missing values with 1400.000
# Column 273: Imputed 6602 missing values with 1900.000
# Column 274: Imputed 3121 missing values with 2800.000
# Column 275: Imputed 6602 missing values with 2200.000
# Column 276: Imputed 6602 missing values with 2200.000
# Column 277: Imputed 3121 missing values with 40800.000
# Column 278: Imputed 6602 missing values with 46600.000
# Column 279: Imputed 6602 missing values with 32000.000
# Column 280: Imputed 3121 missing values with 15000.000
# Column 281: Imputed 6602 missing values with 19600.000
# Column 282: Imputed 6602 missing values with 26000.000
# Column 283: Imputed 3121 missing values with 298600.000
# Column 284: Imputed 6602 missing values with 104300.000
# Column 285: Imputed 6602 missing values with 88200.000
# Column 286: Imputed 3121 missing values with 6800.000
# Column 287: Imputed 6602 missing values with 7900.000
# Column 288: Imputed 6602 missing values with 6800.000
# Column 289: Imputed 3121 missing values with 2200.000
# Column 290: Imputed 6602 missing values with 2700.000
# Column 291: Imputed 6602 missing values with 2300.000
# Column 292: Imputed 3121 missing values with 7000.000
# Column 293: Imputed 6602 missing values with 4200.000
# Column 294: Imputed 6602 missing values with 5300.000
# Column 295: Imputed 3121 missing values with 61100.000
# Column 296: Imputed 6602 missing values with 48100.000
# Column 297: Imputed 6602 missing values with 32000.000
# Column 298: Imputed 3121 missing values with 16100.000
# Column 299: Imputed 6602 missing values with 44300.000
# Column 300: Imputed 6602 missing values with 35600.000
# Column 301: Imputed 3121 missing values with 298600.000
# Column 302: Imputed 6602 missing values with 159500.000
# Column 303: Imputed 6602 missing values with 88200.000
# Column 304: Imputed 3121 missing values with 15200.000
# Column 305: Imputed 6602 missing values with 12400.000
# Column 306: Imputed 6602 missing values with 11000.000
# Column 307: Imputed 3121 missing values with 6100.000
# Column 308: Imputed 6602 missing values with 9600.000
# Column 309: Imputed 6602 missing values with 6100.000
# Column 310: Imputed 3121 missing values with 8100.000
# Column 311: Imputed 6602 missing values with 8300.000
# Column 312: Imputed 6602 missing values with 10900.000
# Column 313: Imputed 3121 missing values with 84100.000
# Column 314: Imputed 6602 missing values with 63200.000
# Column 315: Imputed 6602 missing values with 45100.000
# Column 316: Imputed 3121 missing values with 52700.000
# Column 317: Imputed 6602 missing values with 52700.000
# Column 318: Imputed 6602 missing values with 52700.000
# Column 319: Imputed 3121 missing values with 321200.000
# Column 320: Imputed 6602 missing values with 159500.000
# Column 321: Imputed 6602 missing values with 88200.000
# Column 322: Imputed 3121 missing values with 5263.820
# Column 323: Imputed 6602 missing values with 4945.219
# Column 324: Imputed 6602 missing values with 4705.422
# Column 325: Imputed 3121 missing values with 3524.801
# Column 326: Imputed 6602 missing values with 3799.994
# Column 327: Imputed 6602 missing values with 6308.622
# Column 328: Imputed 3121 missing values with 714900.000
# Column 329: Imputed 6602 missing values with 723400.000
# Column 330: Imputed 6602 missing values with 731660.000
# Column 331: Imputed 7898 missing values with 100000.000
# Column 332: Imputed 11258 missing values with 100000.000
# Column 333: Imputed 11512 missing values with 100000.000
# Column 334: Imputed 3121 missing values with 0.008
# Column 335: Imputed 6602 missing values with 0.009
# Column 336: Imputed 6602 missing values with 0.009
# Column 337: Imputed 3121 missing values with 45350.537
# Column 338: Imputed 6602 missing values with 43580.550
# Column 339: Imputed 6602 missing values with 43602.807
# Column 340: Imputed 3121 missing values with 100.000
# Column 341: Imputed 6602 missing values with 100.000
# Column 342: Imputed 6602 missing values with 100.000
# Column 343: Imputed 3121 missing values with 10277041.406
# Column 344: Imputed 6602 missing values with 10227417.188
# Column 345: Imputed 6602 missing values with 10218603.906
# Column 346: Imputed 3121 missing values with 2.026
# Column 347: Imputed 6602 missing values with 2.069
# Column 348: Imputed 6602 missing values with 2.035
# Column 349: Imputed 3121 missing values with 2524.857
# Column 350: Imputed 6602 missing values with 2509.395
# Column 351: Imputed 6602 missing values with 2060.729
# Column 352: Imputed 3121 missing values with 19423.566
# Column 353: Imputed 6602 missing values with 19148.747
# Column 354: Imputed 6602 missing values with 19043.486
# Column 355: Imputed 3121 missing values with 20910.874
# Column 356: Imputed 6602 missing values with 22327.636
# Column 357: Imputed 6602 missing values with 21564.600
# Column 358: Imputed 3121 missing values with 0.025
# Column 359: Imputed 6602 missing values with 0.016
# Column 360: Imputed 6602 missing values with 0.015
# Column 361: Imputed 3121 missing values with 0.016
# Column 362: Imputed 6602 missing values with 0.014
# Column 363: Imputed 6602 missing values with 0.014
# Column 364: Imputed 3121 missing values with 31340.050
# Column 365: Imputed 6602 missing values with 31281.417
# Column 366: Imputed 6602 missing values with 31263.926
# Column 367: Imputed 3121 missing values with 0.042
# Column 368: Imputed 6602 missing values with 0.035
# Column 369: Imputed 6602 missing values with 0.035
# Column 370: Imputed 3121 missing values with 98.000
# Column 371: Imputed 6602 missing values with 98.000
# Column 372: Imputed 6602 missing values with 98.000
# Column 373: Imputed 3121 missing values with 240.663
# Column 374: Imputed 6602 missing values with 219.142
# Column 375: Imputed 6602 missing values with 154.448
# Column 376: Imputed 3121 missing values with 0.009
# Column 377: Imputed 6602 missing values with 0.013
# Column 378: Imputed 6602 missing values with 0.012
# Column 379: Imputed 3121 missing values with 46.799
# Column 380: Imputed 6602 missing values with 46.799
# Column 381: Imputed 6602 missing values with 46.798
# Column 382: Imputed 3121 missing values with 46.800
# Column 383: Imputed 6602 missing values with 46.800
# Column 384: Imputed 6602 missing values with 46.747
# Column 385: Imputed 3121 missing values with 46.739
# Column 386: Imputed 6602 missing values with 44.668
# Column 387: Imputed 6602 missing values with 46.609
# Column 388: Imputed 3121 missing values with 46.800
# Column 389: Imputed 6602 missing values with 46.800
# Column 390: Imputed 6602 missing values with 46.800
# Column 391: Imputed 3121 missing values with 31310.982
# Column 392: Imputed 6602 missing values with 31261.630
# Column 393: Imputed 6602 missing values with 31236.209
# Column 394: Imputed 3121 missing values with 31206.051
# Column 395: Imputed 6602 missing values with 31187.840
# Column 396: Imputed 6602 missing values with 31158.224
# Column 397: Imputed 3121 missing values with 31088.191
# Column 398: Imputed 6602 missing values with 31060.357
# Column 399: Imputed 6602 missing values with 31094.969
# Column 400: Imputed 3121 missing values with 30970.224
# Column 401: Imputed 6602 missing values with 30958.205
# Column 402: Imputed 6602 missing values with 31039.468
# Column 403: Imputed 3121 missing values with 41683.658
# Column 404: Imputed 6602 missing values with 41213.168
# Column 405: Imputed 6602 missing values with 38970.178
# Column 406: Imputed 3121 missing values with 57086.015
# Column 407: Imputed 6602 missing values with 44707.306
# Column 408: Imputed 6602 missing values with 61532.770
# Column 409: Imputed 3121 missing values with 35731.003
# Column 410: Imputed 6602 missing values with 36374.670
# Column 411: Imputed 6602 missing values with 33520.667
# Column 412: Imputed 3121 missing values with 31023.234
# Column 413: Imputed 6602 missing values with 31107.353
# Column 414: Imputed 6602 missing values with 30939.438
# Column 415: Imputed 3121 missing values with 1626.699
# Column 416: Imputed 6602 missing values with 1437.583
# Column 417: Imputed 6602 missing values with 1482.184
# Column 418: Imputed 3121 missing values with 6553500.000
# Column 419: Imputed 6602 missing values with 6553500.000
# Column 420: Imputed 6602 missing values with 6553500.000
# Column 421: Imputed 34277 missing values with 55720.182
# Column 422: Imputed 37415 missing values with 55720.182
# Column 423: Imputed 37415 missing values with 55720.182
# Column 424: Imputed 18343 missing values with 1238938.587
# Column 425: Imputed 21745 missing values with 1238938.587
# Column 426: Imputed 21745 missing values with 1238938.587
# Column 427: Imputed 10892 missing values with 4428.571
# Column 428: Imputed 14373 missing values with 4428.571
# Column 429: Imputed 14373 missing values with 4428.571
# Column 430: Imputed 103764 missing values with 53.956
# Column 431: Imputed 105528 missing values with 53.956
# Column 432: Imputed 105528 missing values with 53.956
# Column 433: Imputed 92634 missing values with 459194.145
# Column 434: Imputed 95883 missing values with 459194.145
# Column 435: Imputed 96982 missing values with 459194.145
# Column 436: Imputed 94872 missing values with 290723.270
# Column 437: Imputed 99131 missing values with 290723.270
# Column 438: Imputed 98354 missing values with 290723.270
# Column 439: Imputed 3121 missing values with 2800.000
# Column 440: Imputed 3121 missing values with 800.000
# Column 441: Imputed 3121 missing values with 2158.333
# Column 442: Imputed 3121 missing values with 16400.000
# Column 443: Imputed 3121 missing values with 9200.000
# Column 444: Imputed 3121 missing values with 34050.000
# Column 445: Imputed 3121 missing values with 6800.000
# Column 446: Imputed 3121 missing values with 1175.000
# Column 447: Imputed 3121 missing values with 4458.333
# Column 448: Imputed 3121 missing values with 16400.000
# Column 449: Imputed 3121 missing values with 13958.333
# Column 450: Imputed 3121 missing values with 34050.000
# Column 451: Imputed 3121 missing values with 9541.667
# Column 452: Imputed 3121 missing values with 5500.000
# Column 453: Imputed 3121 missing values with 5933.333
# Column 454: Imputed 3121 missing values with 45983.333
# Column 455: Imputed 3121 missing values with 52700.000
# Column 456: Imputed 3121 missing values with 36550.000
# Column 457: Imputed 3121 missing values with 7249.119
# Column 458: Imputed 3121 missing values with 2591.208
# Column 459: Imputed 3121 missing values with 618974.428
# Column 460: Imputed 6883 missing values with 100000.000
# Column 461: Imputed 3121 missing values with 0.007
# Column 462: Imputed 3121 missing values with 42562.529
# Column 463: Imputed 3121 missing values with 0.000
# Column 464: Imputed 3121 missing values with 10163041.081
# Column 465: Imputed 3121 missing values with 1.839
# Column 466: Imputed 3121 missing values with 353.213
# Column 467: Imputed 3121 missing values with 16414.212
# Column 468: Imputed 3121 missing values with 15527.491
# Column 469: Imputed 3121 missing values with 0.006
# Column 470: Imputed 3121 missing values with 0.005
# Column 471: Imputed 3121 missing values with 30930.116
# Column 472: Imputed 3121 missing values with 0.015
# Column 473: Imputed 3121 missing values with 70.249
# Column 474: Imputed 3121 missing values with 94.936
# Column 475: Imputed 3121 missing values with 0.003
# Column 476: Imputed 3121 missing values with 42.843
# Column 477: Imputed 3121 missing values with 43.160
# Column 478: Imputed 3121 missing values with 44.072
# Column 479: Imputed 3121 missing values with 46.800
# Column 480: Imputed 3121 missing values with 30918.723
# Column 481: Imputed 3121 missing values with 30877.363
# Column 482: Imputed 3121 missing values with 30835.605
# Column 483: Imputed 3121 missing values with 30792.804
# Column 484: Imputed 3121 missing values with 32810.309
# Column 485: Imputed 3121 missing values with 25606.564
# Column 486: Imputed 3121 missing values with 29120.395
# Column 487: Imputed 3121 missing values with 30701.252
# Column 488: Imputed 3121 missing values with 985.456
# Column 489: Imputed 3121 missing values with 6553500.000
# Column 490: Imputed 24948 missing values with 53204.375
# Column 491: Imputed 11020 missing values with 1238938.587
# Column 492: Imputed 3121 missing values with 4392.857
# Column 493: Imputed 93197 missing values with 53.895
# Column 494: Imputed 85163 missing values with 420930.390
# Column 495: Imputed 86393 missing values with 290723.270
# Column 497: Imputed 4081 missing values with 100.000
# Column 498: Imputed 8162 missing values with 100.000
# Column 499: Imputed 12243 missing values with 100.000
#
# Imputation Summary:
#   Imputed 364 columns total (showing first 5):
#     Column 45: [0.255, 499.770] → imputed with 49977.010
#     Column 46: [20.771, 1000.000] → imputed with 100000.000
#     Column 84: [-6.687, 557.202] → imputed with 55720.182
#     Column 85: [828.861, 12389.386] → imputed with 1238938.587
#     Column 86: [0.000, 44.286] → imputed with 4428.571
#     ... and 359 more columns
#
# Remaining missing values after imputation: 0
# Output data shape: (185003, 500)
# Output data type: float64

# %%
nowcasting = True
results_df= pd.DataFrame(columns=['year','precision', 'recall', 'f1', 
                                 'precision_base', 'recall_base', 'f1_base'])

y_pred_test = pd.DataFrame(columns=['year', 'month','adm_code','fews_ipc_crisis_pred','fews_ipc_crisis_true'])
#train test split
if nowcasting:
    for year in range(2021,2025):
        # Xtrain, ytrain, Xtest, ytest = train_test_split(X, y, test_ratio = TEST_RATIO)
        (Xtrain, ytrain, Xtrain_loc, Xtrain_group,
        Xtest, ytest, Xtest_loc, Xtest_group) = train_test_split_by_year(
            X, y, X_loc, X_group, df['years'].values, test_year=year)
        ytrain = ytrain.astype(int)
        ytest  = ytest.astype(int)
        Xtrain_L1 = Xtrain[:, l1_index]
        Xtrain_L2 = Xtrain[:, l2_index]
        Xtest_L1 = Xtest[:, l1_index]
        Xtest_L2 = Xtest[:, l2_index]
        # if evaluating later
        #define georf
        #max_model_depth: max depth of the hierarchical partitioning in GeoRF
        #max_depth: max depth of each tree in random forest (10 used in demo to reduce execution time)
        #n_jobs: number of cores to use to run the model in parallel
        georf = GeoRF(min_model_depth = MIN_DEPTH,	max_model_depth = MAX_DEPTH, n_jobs = N_JOBS, max_depth=5)#, max_depth=10
        #definition with all parameters
        #dir: defaulted to "result" in code (auto-generated), no need to change
        # georf = GeoRF(min_model_depth = MIN_DEPTH,	max_model_depth = MAX_DEPTH, dir = "",
        # 							n_trees_unit = 100, num_class = NUM_CLASS, max_depth=None, random_state=5, n_jobs = N_JOBS,
        # 							mode=MODE, name = 'RF', type = 'static', sample_weights_by_class = None)
        #training
        georf.fit(Xtrain_L1, ytrain, Xtrain_group, val_ratio = VAL_RATIO)
        #preidct
        ypred_L1 = georf.predict(Xtest_L1, Xtest_group)
        error = ytest-ypred_L1
        georf.fit(Xtrain_L2, error, Xtrain_group, val_ratio = VAL_RATIO)
        
        y_pred_L2 = georf.predict(Xtest_L2, Xtest_group)  # predict L2
        
        ypred = ypred_L1 + y_pred_L2  # combine L1 and L2 predictions
        #evaluatipn
        (pre, rec, f1,
        pre_base, rec_base, f1_base) = georf.evaluate(Xtest, ytest, Xtest_group, eval_base = True, print_to_file = True)
        # manually calculate precision, recall, f1
        pre = precision_score(ytest, ypred, average='weighted')
        rec = recall_score(ytest, ypred, average='weighted')
        f1 = f1_score(ytest, ypred, average='weighted')
        results_df = pd.concat([results_df, pd.DataFrame({'year': year,'precision':pre , 'recall': rec, 'f1': f1, 'precision_base': pre_base[1], 'recall_base': rec_base[1], 'f1_base': f1_base[1]}, index=[0])],ignore_index=True)
        y_pred_test = pd.concat([y_pred_test, pd.DataFrame({'year': year, 'month': Xtest[:,1], 'adm_code':Xtest[:,0], 'fews_ipc_crisis_pred': ypred, 'fews_ipc_crisis_true': ytest})], ignore_index=True)
        # output y_pred_test and results_df to csv
    y_pred_test.to_csv('y_pred_test_gpn.csv', index=False)
    results_df.to_csv('results_df_gpn.csv', index=False)
else:
    for year in range(2021,2025):
        # Xtrain, ytrain, Xtest, ytest = train_test_split(X, y, test_ratio = TEST_RATIO)
        (Xtrain, ytrain, Xtrain_loc, Xtrain_group,
        Xtest, ytest, Xtest_loc, Xtest_group) = train_test_split_by_year(
            X, y, X_loc, X_group, df['years'].values, test_year=year)
        ytrain = ytrain.astype(int)
        ytest  = ytest.astype(int)        # if evaluating later
        #define georf
        #max_model_depth: max depth of the hierarchical partitioning in GeoRF
        #max_depth: max depth of each tree in random forest (10 used in demo to reduce execution time)
        #n_jobs: number of cores to use to run the model in parallel
        georf = GeoRF(min_model_depth = MIN_DEPTH,	max_model_depth = MAX_DEPTH, n_jobs = N_JOBS, max_depth=5)#, max_depth=10
        #definition with all parameters
        #dir: defaulted to "result" in code (auto-generated), no need to change
        # georf = GeoRF(min_model_depth = MIN_DEPTH,	max_model_depth = MAX_DEPTH, dir = "",
        # 							n_trees_unit = 100, num_class = NUM_CLASS, max_depth=None, random_state=5, n_jobs = N_JOBS,
        # 							mode=MODE, name = 'RF', type = 'static', sample_weights_by_class = None)
        #training
        georf.fit(Xtrain, ytrain, Xtrain_group, val_ratio = VAL_RATIO)
        #preidct
        ypred = georf.predict(Xtest, Xtest_group)
        #evaluatipn
        (pre, rec, f1,
        pre_base, rec_base, f1_base) = georf.evaluate(Xtest, ytest, Xtest_group, eval_base = True, print_to_file = True)
        results_df = pd.concat([results_df, pd.DataFrame({'year': year,'precision':pre[1] , 'recall': rec[1], 'f1': f1[1], 'precision_base': pre_base[1], 'recall_base': rec_base[1], 'f1_base': f1_base[1]}, index=[0])],ignore_index=True)
        y_pred_test = pd.concat([y_pred_test, pd.DataFrame({'year': year, 'month': Xtest[:,1], 'adm_code':Xtest[:,0], 'fews_ipc_crisis_pred': ypred, 'fews_ipc_crisis_true': ytest})], ignore_index=True)
        # output y_pred_test and results_df to csv
    y_pred_test.to_csv('y_pred_test_gpf.csv', index=False)
    results_df.to_csv('results_df_gpf.csv', index=False)
# Out:
# model_dir: result_GeoRF_8
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\helper.py:235: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   s_branch[''][:gid_list.shape[0]] = gid_list
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\partition_opt.py:465: RuntimeWarning: invalid value encountered in divide
#   q_init = np.nan_to_num(c/b)
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\partition_opt.py:465: RuntimeWarning: invalid value encountered in divide
#   q_init = np.nan_to_num(c/b)
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\sig_test.py:107: RuntimeWarning: divide by zero encountered in scalar divide
#   es = mean_diff / mean_diff_base_before
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\partition_opt.py:465: RuntimeWarning: invalid value encountered in divide
#   q_init = np.nan_to_num(c/b)
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\partition_opt.py:465: RuntimeWarning: invalid value encountered in divide
#   q_init = np.nan_to_num(c/b)
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\sig_test.py:107: RuntimeWarning: divide by zero encountered in scalar divide
#   es = mean_diff / mean_diff_base_before
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\partition_opt.py:465: RuntimeWarning: invalid value encountered in divide
#   q_init = np.nan_to_num(c/b)
# c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\sig_test.py:107: RuntimeWarning: divide by zero encountered in scalar divide
#   es = mean_diff / mean_diff_base_before
# model_dir: result_GeoRF_8
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 35
#      33 ypred_L1 = georf.predict(Xtest_L1, Xtest_group)
#      34 error = ytest-ypred_L1
# ---> 35 georf.fit(Xtrain_L2, error, Xtrain_group, val_ratio = VAL_RATIO)
#      37 y_pred_L2 = georf.predict(Xtest_L2, Xtest_group)  # predict L2
#      39 ypred = ypred_L1 + y_pred_L2  # combine L1 and L2 predictions
#
# File c:\Users\swl00\IFPRI Dropbox\Weilun Shi\Google fund\Analysis\2.source_code\Step5_Geo_RF_trial\STAR\Tree-based-models\GeoRF.py:199, in GeoRF.fit(self, X, y, X_group, X_set, val_ratio, print_to_file)
#     196 if MODEL_CHOICE == 'RF':
#     197 	#RF
#     198 	self.model = RFmodel(self.dir_ckpt, self.n_trees_unit, max_depth = self.max_depth)#can add sample_weights_by_class
# --> 199 	self.model.train(X[train_list_init], y[train_list_init], branch_id = '', sample_weights_by_class = self.sample_weights_by_class)
#     201 self.model.save('')#save root branch
#     203 print("Time single: %f s" % (time.time() - start_time))
#
# IndexError: index 10397 is out of bounds for axis 0 with size 10397
